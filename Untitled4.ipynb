# %%
import pandas as pd

# %%
df= pd.read_csv("/content/Time_series_analysis_and_forecast_DATASET.csv")

# %%
df.head()
# Out:
#               FullDate  Tmax   SysLoad  GasPrice  ElecPrice
# 0  2010-09-01 00:00:00  15.8  1688.215      3.69     23.710
# 1  2010-09-01 01:00:00  15.8  1669.195      3.69     22.635
# 2  2010-09-01 02:00:00  15.8  1491.980      3.69     22.565
# 3  2010-09-01 03:00:00  15.8  1330.760      3.69     18.910
# 4  2010-09-01 04:00:00  15.8  1247.940      3.69     18.030

# %%
df.set_index(df.FullDate, inplace=True)
df.drop('FullDate', axis=1, inplace=True)
df.head()
# Out:
#                      Tmax   SysLoad  GasPrice  ElecPrice
# FullDate
# 2010-09-01 00:00:00  15.8  1688.215      3.69     23.710
# 2010-09-01 01:00:00  15.8  1669.195      3.69     22.635
# 2010-09-01 02:00:00  15.8  1491.980      3.69     22.565
# 2010-09-01 03:00:00  15.8  1330.760      3.69     18.910
# 2010-09-01 04:00:00  15.8  1247.940      3.69     18.030

# %%
df.index=pd.to_datetime(df.index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92016 entries, 2010-09-01 00:00:00 to 2021-02-28 23:00:00
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Tmax       92016 non-null  float64
#  1   SysLoad    92016 non-null  float64
#  2   GasPrice   92016 non-null  float64
#  3   ElecPrice  92016 non-null  float64
# dtypes: float64(4)
# memory usage: 3.5 MB

# %%
df.head()
# Out:
#                      ElecPrice
# FullDate
# 2010-09-01 00:00:00     23.710
# 2010-09-01 01:00:00     22.635
# 2010-09-01 02:00:00     22.565
# 2010-09-01 03:00:00     18.910
# 2010-09-01 04:00:00     18.030

# %%
day= df.resample("1D").sum().fillna(method='ffill')

# %%
df.drop(columns=["SysLoad","GasPrice", "Tmax"], inplace=True)

# %%
day.plot()
# Out:
# <Axes: xlabel='FullDate'>

# %%
#Importing the relevant
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
adf=pd.read_csv("/content/Time_series_analysis_and_forecast_DATASET.csv")
adf.head()
# Out:
#               FullDate  Tmax   SysLoad  GasPrice  ElecPrice
# 0  2010-09-01 00:00:00  15.8  1688.215      3.69     23.710
# 1  2010-09-01 01:00:00  15.8  1669.195      3.69     22.635
# 2  2010-09-01 02:00:00  15.8  1491.980      3.69     22.565
# 3  2010-09-01 03:00:00  15.8  1330.760      3.69     18.910
# 4  2010-09-01 04:00:00  15.8  1247.940      3.69     18.030

# %%
adf['Full']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92016 entries, 0 to 92015
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FullDate   92016 non-null  object
#  1   Tmax       92016 non-null  float64
#  2   SysLoad    92016 non-null  float64
#  3   GasPrice   92016 non-null  float64
#  4   ElecPrice  92016 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.5+ MB

# %%
day= adf['ElecPrice'].resample("1D").sum().fillna(method='ffill')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-cdc950b99329> in <cell line: 1>()
# ----> 1 day= adf['ElecPrice'].resample("1D").sum().fillna(method='ffill')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    5870         group_keys: bool | lib.NoDefault = no_default,
#    5871     ) -> Resampler:
# -> 5872         return super().resample(
#    5873             rule=rule,
#    5874             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    8856
#    8857         axis = self._get_axis_number(axis)
# -> 8858         return get_resampler(
#    8859             self,
# ...

# %%
result = adfuller(adf['SysLoad', 'GasPrice'], autolag='AIC')

# %%
df.index.min()
# Out:
# Timestamp('2010-09-01 00:00:00')

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.ar_model import AutoReg

# %% [markdown]
# **FACEBOOK PIPETH**

# %%
# !pip install prophet

# %%
from prophet import Prophet
